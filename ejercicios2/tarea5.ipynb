# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("pseudoCongr10.csv",header=None)
data1.hist(bins=10)
plt.title("10 pseudoaleatorios Fortran")
plt.ylabel("Frecuencia")
plt.xlabel("Valor")
# Out:
# Text(0.5, 0, 'Valor')

# %%
data2 = pd.read_csv("pseudoCongr1000.csv",header=None)
data2.hist(bins=10)
plt.title("1000 pseudoaleatorios Fortran")
plt.ylabel("Frecuencia")
plt.xlabel("Valor")
# Out:
# Text(0.5, 0, 'Valor')

# %%
data3 = pd.read_csv("/mnt/c/Users/sfons/OneDrive - Universidad de La Frontera/Universidad/Sem9/Monte Carlo/MATLAB_10rand.csv",header=None)
data3.hist(bins=10)
plt.title("10 pseudoaleatorios MATLAB")
plt.ylabel("Frecuencia")
plt.xlabel("Valor")
# Out:
# Text(0.5, 0, 'Valor')

# %%
data4 = pd.read_csv("/mnt/c/Users/sfons/OneDrive - Universidad de La Frontera/Universidad/Sem9/Monte Carlo/MATLAB_1000rand.csv",header=None)
data4.hist(bins=10)
plt.title("1000 pseudoaleatorios MATLAB")
plt.ylabel("Frecuencia")
plt.xlabel("Valor")
# Out:
# Text(0.5, 0, 'Valor')
