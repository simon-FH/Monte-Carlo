# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("data_out_mil.csv",header=None)
data1.hist(bins=11)
plt.title("Suma caras de dos dados")
plt.ylabel("Frecuencia")
plt.xlabel("Valor")
# Out:
# Text(0.5, 0, 'Valor')

# %%
data2 = pd.read_csv("data_out_millon.csv",header=None)
data2.hist(bins=11)
plt.title("Suma caras de dos dados")
plt.ylabel("Frecuencia")
plt.xlabel("Valor")
# Out:
# Text(0.5, 0, 'Valor')
