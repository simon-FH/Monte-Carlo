# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv("data_out_3_mil.csv",header=None)
plt.plot(data1[0],data1[1], linestyle='', marker='.')

# %%
data2 = pd.read_csv("data_out_3_millon.csv",header=None)
plt.plot(data2[0],data2[1], linestyle='', marker='.', markersize=.05)
